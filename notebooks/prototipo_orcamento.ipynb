# %%
from pathlib import Path
import pandas as pd
from openpyxl import load_workbook
import os
import numpy as np
import pickle

# %%
pd.set_option("display.max_columns", None)

# %%
PATH_FILES_ONE_DRIVE = Path(r'C:\Users\h-pgy\one_drive_prefs\OneDrive - Default Directory\Shared Documents\Estruturação do PDM 2021-2024\Elaboração PDM Versão Final')

# %%
class PlanilhaNotFound(ValueError):
    '''Raised quando nao consegue achar planilha para a meta'''

# %%
def listar_metas_ok():
    
    controle = pd.read_excel(PATH_FILES_ONE_DRIVE/'Controle das Devolutivas.xlsx')
    
    filtro_preench = controle['Aba Orçamento preenchida corretamente?'].str.lower().str.strip()=='sim'
    filtro_analis = controle['Aba orçamento já analisada?'].str.lower().str.strip()=='sim'
    
    for m in controle[~(filtro_preench&filtro_analis)]['Meta'].unique():
        print(f'Meta {m} não está ok no controle')
    
    return controle[filtro_preench&filtro_analis]['Meta'].values

# %%
def get_planilhas(folder_original):
        
        fpaths =  [os.path.join(folder_original, file) for file in 
                    os.listdir(folder_original) if 'xls' 
                    in file.split('.')[-1]]
        
        return fpaths

# %%
def read_workbook(file):

    wb = load_workbook(file, read_only=True, data_only=True)

    return wb

# %%
def match_planilha(wb, num_meta):
        
        sheet = wb['Ficha técnica Meta ']
        
        num_meta_planilha = sheet['C5'].value
        
        if str(num_meta_planilha) == str(num_meta):
            return True

# %%
def find_planilha(files, num_meta):
    
    for file in files:
        
        wb = read_workbook(file)
        
        if match_planilha(wb, num_meta):
            secretaria = wb['Ficha técnica Meta ']['C4'].value
            files.remove(file) # remove para dar uma otimizada nas próximas buscas
            return file, secretaria
    else:
        raise PlanilhaNotFound(f'Planilha não encontrada para a meta {num_meta}')

# %%
def planilhao(lista_ok = None, path_xls = None, lista_dfs = None):
    
    if path_xls is None:
        path_xls = PATH_FILES_ONE_DRIVE/'Fichas Metas\Devolutiva 11-jun'
        
    if lista_ok is None:
        lista_ok = listar_metas_ok()
        
    if lista_dfs is None:
        lista_dfs = []
    
    f_paths = get_planilhas(path_xls)
        
    for meta in lista_ok:
        print(f'Puxando dados meta {meta}')
        try:
            file, secretaria = find_planilha(f_paths, meta)
        except PlanilhaNotFound as e:
            print(e)
            continue
        df = pd.read_excel(file, sheet_name = 'Orçamento', thousands = '.',
                          dtype = {'Código Ação' : str})
        df['meta'] = meta
        df['secretaria'] = secretaria
        lista_dfs.append(df)
    
    return pd.concat(lista_dfs)

# %%
#lista_dfs = []
#df = planilhao(lista_dfs = lista_dfs)
# Out:
# Meta 1 não está ok no controle
# Meta 10 não está ok no controle
# Meta 11 não está ok no controle
# Meta 12 não está ok no controle
# Meta 53 não está ok no controle
# Meta 54 não está ok no controle
# Meta 60 não está ok no controle
# Meta 61 não está ok no controle
# Meta 62 não está ok no controle
# Meta 64 não está ok no controle
# Meta 69 não está ok no controle
# Meta 72 não está ok no controle
# Meta 75 não está ok no controle
# Meta SMSU Nova 1 não está ok no controle
# Meta SGM.Nova1 não está ok no controle
# Meta SGM.Nova2 não está ok no controle
# Meta 3.2 não está ok no controle
# Meta 5.2 não está ok no controle
# Meta nan não está ok no controle
# Puxando dados meta 2
# Puxando dados meta 3.1
# Puxando dados meta 4
# Puxando dados meta 5.1
# Puxando dados meta 6
# Puxando dados meta 7
# Puxando dados meta 8
# Puxando dados meta 9
# Puxando dados meta 13
# Puxando dados meta 14
# Puxando dados meta 15
# Puxando dados meta 16
# Puxando dados meta 17
# Puxando dados meta 18
# Puxando dados meta 19
# Puxando dados meta 20
# Puxando dados meta 21
# Puxando dados meta 22
# Puxando dados meta 23
# Puxando dados meta 24
# Puxando dados meta 25
# Puxando dados meta 26
# Puxando dados meta 27
# Puxando dados meta 28
# Puxando dados meta 29
# Puxando dados meta 30
# Puxando dados meta 31
# Puxando dados meta 32
# Puxando dados meta 33
# Puxando dados meta 34
# Puxando dados meta 35
# Puxando dados meta 36
# Puxando dados meta 37
# Puxando dados meta 38
# Puxando dados meta 39
# Puxando dados meta 40
# Puxando dados meta 41
# Puxando dados meta 42
# Puxando dados meta 43
# Puxando dados meta 44
# Puxando dados meta 45
# Puxando dados meta 46
# Puxando dados meta 47
# Puxando dados meta 48
# Puxando dados meta 49
# Puxando dados meta 50
# Puxando dados meta 51
# Puxando dados meta 52
# Puxando dados meta 55
# Puxando dados meta 56
# Puxando dados meta 57
# Puxando dados meta 58
# Puxando dados meta 59
# Puxando dados meta 63
# Puxando dados meta 65
# Puxando dados meta 66
# Puxando dados meta 67
# Puxando dados meta 68
# Puxando dados meta 70
# Puxando dados meta 71
# Puxando dados meta 73
# Puxando dados meta 74
# Puxando dados meta 52.1
# Puxando dados meta 54.2
# Puxando dados meta 54.3
# Puxando dados meta 52.2
# Puxando dados meta 54.4
# Puxando dados meta 52.3

# %%
#with open('planilhao_2.pi', 'wb') as f:
#    pickle.dump(df, f)

# %%
with open('planilhao.pi', 'rb') as f:
    df = pickle.load(f)

# %%
def dropar_unnamed(df):
    
    unnameds = [col for col in df if
               col.startswith('Unnamed: ')]
    
    df.drop(unnameds, axis = 1, inplace = True)
    for col in df:
        if col.startswith('Unnamed: '):
            df.drop(col, axis = 1, )

# %%
dropar_unnamed(df)

# %%
sem_na = df.dropna(how='all', subset = [col for col in df.columns if col not in ('meta', 'secretaria')]).copy()

# %%
def pegar_objetivos(df):
    
    objetivos = pd.read_excel(PATH_FILES_ONE_DRIVE/'Metas com Objetivos atualizados 18-06-21.xlsx')
    
    merged = df.merge(objetivos, how = 'left', 
                      right_on = 'Nº meta PdM ',  left_on = 'meta').copy()
    
    merged.drop(['Redação da Meta PdM ','Nº meta PdM '],
               axis = 1, inplace = True)
    
    return merged

# %%
sem_na = pegar_objetivos(sem_na)

# %%
def arrumar_meta(item):
    
    item = str(item)
    
    antes, depois = item.split('.')
    
    if int(depois) > 0:
        return f'{antes}.{depois}'
    else:
        return antes

# %%
sem_na['meta'] = sem_na['meta'].apply(arrumar_meta)

# %%
def add_ponto_acao(item):
    
    item = str(item)
    
    if item == 'nan':
        return 'XX.XX.XXXX.XX'
    else:
        return f'{item[:2]}.{item[2:4]}.{item[4:8]}.{item[8:10]}'

# %%
def gerar_colunas_dotacao(df):
    
    
    df = df.copy()
    df['Código Ação'] = df['Código Ação'].apply(add_ponto_acao)
    df['Unidade Orçamentária'] = df['Código Ação'].apply(lambda x: '.'.join(x.split('.')[:2]))
    df['Ação'] = df['Código Ação'].apply(lambda x: x.split('.')[2])
    df['Fonte'] = df['Código Ação'].apply(lambda x: x.split('.')[3])
    
    return df

# %%
sem_na = gerar_colunas_dotacao(sem_na)

# %%
ordem_cols = [
    'Objetivo Estratégico Atualizado',
    'secretaria',
    'meta',
    'IN',
    'Item',
    'Custeio/\nInvestimento',
    'Código Ação',
    'Unidade Orçamentária',
    'Ação',
    'Fonte',
    'classif.',
    'V. Atualizado',
    'V. Congelado',
    'V. Disponível',
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024',
    'Custo TOTAL',
     
     ]

# %%
sem_na = sem_na[ordem_cols]

# %%
sem_na.to_excel('teste_planilhao_orcamento_4.xlsx', index = False)

# %%
colunas_numericas = [
'V. Atualizado',
'V. Congelado',                       
'V. Disponível',                        
'Atualizado (Disponibilizado PDM)',
'Congelado (Dispon. PDM)',    
'Disponível (Dispon. PDM)',             
'Custo 2021',            
'Custo 2022',                          
'Custo 2023',                          
'Custo 2024',                          
'Custo TOTAL']

# %%
df[df.eq('Não se aplica').any(1)]
# Out:
#   IN Item Custeio/\nInvestimento    Código Ação  classif. V. Atualizado  \
# 0  a    1          Não se aplica  Não se aplica  execução           NaN
# 3  c    1          Não se aplica  Não se aplica  execução           NaN
# 3  c    1          Não se aplica  Não se aplica  execução           NaN
#
#   V. Congelado V. Disponível Atualizado (Disponibilizado PDM)  \
# 0          NaN           NaN                    Não se aplica
# 3          NaN           NaN                    Não se aplica
# 3          NaN           NaN                    Não se aplica
#
#   Congelado (Dispon. PDM) Disponível (Dispon. PDM)     Custo 2021  \
# 0           Não se aplica                      NaN  Não se aplica
# 3           Não se aplica                      NaN            0.0
# 3           Não se aplica                      NaN            0.0
#
#       Custo 2022     Custo 2023     Custo 2024 Custo TOTAL  meta secretaria
# 0  Não se aplica  Não se aplica  Não se aplica         0.0  20.0        SME
# 3            0.0            0.0            0.0         0.0  21.0        SME
# 3            0.0            0.0            0.0         0.0  22.0        SME

# %%
def solve_numero(item):
    
    if item == 'Não se aplica':
        return np.nan
    if type(item) in (float, int):
        return item
    elif type(item) is str:
        try:
            float(item)
        except ValueError:
            try:
                item = item.replace('.', '')
                item = item.replace(',', '.')
                return float(item)
            except ValueError:
                print(f'Item {item} fora do padrão')
                return np.nan
    else:
        print(type(item))

# %%
numerico = sem_na.copy()
for col in colunas_numericas:
    numerico[col] = numerico[col].apply(solve_numero)

# %%
numerico.dtypes
# Out:
# Objetivo Estratégico Atualizado      object
# secretaria                           object
# meta                                 object
# IN                                   object
# Item                                 object
# Custeio/\nInvestimento               object
# Código Ação                          object
# Unidade Orçamentária                 object
# Ação                                 object
# Fonte                                object
# classif.                             object
# V. Atualizado                       float64
# V. Congelado                        float64
# V. Disponível                       float64
# Atualizado (Disponibilizado PDM)    float64
# Congelado (Dispon. PDM)             float64
# Disponível (Dispon. PDM)            float64
# Custo 2021                          float64
# Custo 2022                          float64
# Custo 2023                          float64
# Custo 2024                          float64
# Custo TOTAL                         float64
# dtype: object

# %%
n_pode_vazio = [
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024'
]

# %%
for col in n_pode_vazio:
    soma = numerico[col].isnull().sum()
    if  soma > 0:
        print(col, soma)
# Out:
# Atualizado (Disponibilizado PDM) 6
# Congelado (Dispon. PDM) 10
# Disponível (Dispon. PDM) 15
# Custo 2021 14
# Custo 2022 12
# Custo 2022 12
# Custo 2023 11
# Custo 2024 11

# %%
dropar_categoricas = (numerico['classif.'].isnull()|numerico['Custeio/\nInvestimento'].isnull())

# %%
numerico[dropar_categoricas]
# Out:
#                        Objetivo Estratégico Atualizado secretaria meta   IN  \
# 2    Garantir à população atendimento integral em s...        SMS    2  NaN
# 6    Garantir à população atendimento integral em s...        SMS    4  NaN
# 425  Promover a transparência e a integridade dos ó...        CGM   73  NaN
#
#     Item Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação  \
# 2    NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 6    NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 425  NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
#
#     Fonte classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 2      XX      NaN            NaN           NaN            NaN
# 6      XX      NaN            NaN           NaN            NaN
# 425    XX      NaN            NaN           NaN            NaN
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 2                                 NaN                      NaN
# 6                                 NaN                      NaN
# 425                               NaN                      NaN
#
#      Disponível (Dispon. PDM)  Custo 2021  Custo 2022  Custo 2023  Custo 2024  \
# 2                         NaN         NaN         NaN         0.0         NaN
# 6                         NaN         NaN         NaN         NaN         0.0
# 425                       NaN         NaN         NaN         NaN         NaN
#
#      Custo TOTAL
# 2            NaN
# 6            NaN
# 425     150000.0

# %%
limpo = numerico[~dropar_categoricas].copy()

# %%
dropar_numericas = (limpo['Atualizado (Disponibilizado PDM)'].isnull()|
                    limpo['Congelado (Dispon. PDM)'].isnull()|
                    limpo['Disponível (Dispon. PDM)'].isnull()|
                    limpo['Custo 2021'].isnull()|
                    limpo['Custo 2022'].isnull()|
                    limpo['Custo 2023'].isnull()|
                    limpo['Custo 2024'].isnull())

# %%
dropar_numericas.sum()
# Out:
# 26

# %%
limpo[dropar_numericas]
# Out:
#                        Objetivo Estratégico Atualizado secretaria meta   IN  \
# 76   Garantir à toda população em idade escolar o a...        SME   20    a
# 80   Garantir à toda população em idade escolar o a...        SME   20    d
# 81   Garantir à toda população em idade escolar o a...        SME   20    d
# 85   Garantir à toda população em idade escolar o a...        SME   21    c
# 99   Garantir à toda população em idade escolar o a...        SME   21    e
# 103  Garantir à toda população em idade escolar o a...        SME   22    c
# 117  Garantir à toda população em idade escolar o a...        SME   22    e
# 128  Democratizar o acesso a políticas públicas de ...       SEME   26    b
# 129  Democratizar o acesso a políticas públicas de ...       SEME   26    c
# 143  Ampliar a resiliência da cidade às chuvas, red...      SMSUB   31    A
# 147  Garantir a qualidade e segurança das vias públ...      SMSUB   33    A
# 148  Garantir a qualidade e segurança das vias públ...      SMSUB   33    A
# 194  Atingir grau de excelência em segurança viária...        SMT   37    a
# 265  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    c
# 266  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    d
# 267  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    e
# 268  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    g
# 269  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    g
# 270  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    g
# 271  Garantir o acesso ao Sistema Municipal de Tran...        SMT   42    g
# 283  Garantir o acesso ao Sistema Municipal de Tran...        SMT   44    a
# 386  Assegurar o acesso à internet como direito fun...       SMIT   57    d
# 406  Proteger, recuperar e aprimorar a qualidade am...      SMSUB   67    I
# 422  Promover a transparência e a integridade dos ó...        CGM   73    c
# 423  Promover a transparência e a integridade dos ó...        CGM   73    e
# 424  Promover a transparência e a integridade dos ó...        CGM   73  NaN
#
#     Item Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação  \
# 76     1          Não se aplica  Nã.o .se a.pl                Nã.o   se a
# 80     2                Custeio  16.10.2831.00                16.10  2831
# 81     3                Custeio  16.10.2180.00                16.10  2180
# 85     1          Não se aplica  Nã.o .se a.pl                Nã.o   se a
# 99     1                Custeio  16.10.2820.00                16.10  2820
# 103    1          Não se aplica  Nã.o .se a.pl                Nã.o   se a
# 117    1                custeio  16.10.2820.00                16.10  2820
# 128    2                Custeio  19.10.2397.00                19.10  2397
# 129    3                Custeio  19.10.2397.00                19.10  2397
# 143    1                Custeio  xx..x.x.xx.xx                  xx.     x
# 147    3                Custeio  12.10.2340.00                12.10  2340
# 148    4                Custeio  12.10.2340.00                12.10  2340
# 194   42           Investimento  98.20.3757.08                98.20  3757
# 265    1                Custeio  20.10.4701.00                20.10  4701
# 266    1           Investimento  20.10.1095.00                20.10  1095
# 267    1           Investimento  20.10.1095.00                20.10  1095
# 268    1           Investimento  20.10.1095.00                20.10  1095
# 269    2           Investimento  20.10.1095.00                20.10  1095
# 270    3           Investimento  20.10.1095.00                20.10  1095
# 271    4           Investimento  20.10.1095.00                20.10  1095
# 283    8           Investimento  20.10.1099.00                20.10  1099
# 386    1                custeio  23.10.4305.00                23.10  4305
# 406    2           investimento  81.10.6006.00                81.10  6006
# 422  1.0                Custeio  32.10.2100.00                32.10  2100
# 423  1.0                Custeio  32.10.2100.00                32.10  2100
# 424  NaN                Custeio  32.10.8262.00                32.10  8262
#
#     Fonte       classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 76     pl       execução            NaN           NaN            NaN
# 80     00       execução   5.359134e+07           0.0   5.359134e+07
# 81     00       execução   1.435809e+07           0.0   1.435809e+07
# 85     pl       execução            NaN           NaN            NaN
# 99     00       execução   9.507020e+05           0.0   9.507020e+05
# 103    pl       execução            NaN           NaN            NaN
# 117    00       execução   9.507020e+05           0.0   9.507020e+05
# 128    00       execução   2.501000e+06        1000.0   2.500000e+06
# 129    00       execução   2.501000e+06        1000.0   2.500000e+06
# 143     x  contrapartida            NaN           NaN            NaN
# 147    00       execução   1.113350e+08           0.0   1.113350e+08
# 148    00       execução   1.113350e+08           0.0   1.113350e+08
# 194    08       execução   1.815000e+07    18150000.0   0.000000e+00
# 265    00       execução   2.250000e+09           0.0   2.250000e+09
# 266    00       execução   1.000000e+03        1000.0   0.000000e+00
# 267    00       execução   1.000000e+03        1000.0   0.000000e+00
# 268    00       execução   1.000000e+03        1000.0   0.000000e+00
# 269    00       execução   1.000000e+03        1000.0   0.000000e+00
# 270    00       execução   1.000000e+03        1000.0   0.000000e+00
# 271    00       execução   1.000000e+03        1000.0   0.000000e+00
# 283    00       execução   1.000000e+03        1000.0   0.000000e+00
# 386    00       execução   4.100000e+05           0.0   4.100000e+05
# 406    00       execução   2.327007e+07           0.0   2.327007e+07
# 422    00       execução   2.677409e+07        2000.0   2.677309e+07
# 423    00       execução   2.677409e+07        2000.0   2.677309e+07
# 424    00  contrapartida   3.750430e+05           0.0   3.750430e+05
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 76                                NaN                      NaN
# 80                               0.00                      0.0
# 81                               0.00                      0.0
# 85                                NaN                      NaN
# 99                               0.00                      0.0
# 103                               NaN                      NaN
# 117                              0.00                      0.0
# 128                              0.00                      0.0
# 129                              0.00                      0.0
# 143                        8599612.25                      0.0
# 147                              0.00                      0.0
# 148                              0.00                      0.0
# 194                              0.00                      0.0
# 265                              0.00                      0.0
# 266                              0.00                      0.0
# 267                              0.00                      0.0
# 268                              0.00                      0.0
# 269                              0.00                      0.0
# 270                              0.00                      0.0
# 271                              0.00                      0.0
# 283                              0.00                      0.0
# 386                              0.00                      0.0
# 406                              0.00                      NaN
# 422                          15000.00                      NaN
# 423                          15000.00                      NaN
# 424                          16000.00                      NaN
#
#      Disponível (Dispon. PDM)   Custo 2021    Custo 2022    Custo 2023  \
# 76                        NaN          NaN           NaN           NaN
# 80                        NaN          0.0  5.040000e+03  5.292000e+03
# 81                        NaN          0.0  6.788250e+03  7.127660e+03
# 85                        NaN          0.0  0.000000e+00  0.000000e+00
# 99                        NaN          0.0  1.050000e+06  0.000000e+00
# 103                       NaN          0.0  0.000000e+00  0.000000e+00
# 117                       NaN          0.0  1.050000e+06  0.000000e+00
# 128                       NaN          0.0  5.550000e+05  1.110000e+06
# 129                       NaN          0.0  1.105000e+06  1.215500e+06
# 143                8599612.25          NaN           NaN           NaN
# 147                       NaN  162455400.0  1.787009e+08  1.965710e+08
# 148                       NaN   16575000.0  1.823250e+07  2.005575e+07
# 194                      0.00          NaN  2.000000e+06  2.000000e+06
# 265                      0.00          NaN           NaN           NaN
# 266                      0.00          NaN           NaN           NaN
# 267                      0.00          NaN           NaN           NaN
# 268                      0.00          NaN           NaN           NaN
# 269                      0.00          NaN           NaN           NaN
# 270                      0.00          NaN           NaN           NaN
# 271                      0.00          NaN           NaN           NaN
# 283                      0.00          NaN  6.900000e+06  0.000000e+00
# 386                       NaN     100000.0  1.000000e+05  1.000000e+05
# 406                      0.00          0.0  2.886885e+05  3.031230e+05
# 422                  15000.00      31000.0  4.200000e+04  3.200000e+04
# 423                  15000.00          0.0  7.000000e+03  7.000000e+03
# 424                  16000.00          0.0  0.000000e+00  0.000000e+00
#
#        Custo 2024   Custo TOTAL
# 76            NaN  0.000000e+00
# 80   5.556600e+03  1.588860e+04
# 81   7.484050e+03  2.139996e+04
# 85   0.000000e+00  0.000000e+00
# 99   1.050000e+06  2.100000e+06
# 103  0.000000e+00  0.000000e+00
# 117  1.050000e+06  2.100000e+06
# 128  1.665000e+06  3.330000e+06
# 129  1.337050e+06  3.657550e+06
# 143           NaN  0.000000e+00
# 147  2.162281e+08  7.539555e+08
# 148  2.206132e+07  7.692458e+07
# 194  2.000000e+06  6.000000e+06
# 265           NaN           NaN
# 266           NaN  6.000000e+06
# 267           NaN  4.000000e+06
# 268           NaN           NaN
# 269           NaN  3.147381e+06
# 270           NaN  1.049127e+08
# 271           NaN  1.080601e+07
# 283  0.000000e+00  6.900000e+06
# 386  1.000000e+05  4.000000e+05
# 406  2.886885e+05  8.805000e+05
# 422  2.400000e+04  1.290000e+05
# 423  7.000000e+03  2.100000e+04
# 424  0.000000e+00  0.000000e+00

# %%
# a principio nao vamos limpar as numericas
#limpo = limpo[~dropar_numericas].copy()

# %%
limpo[limpo['Objetivo Estratégico Atualizado'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Objetivo Estratégico Atualizado, secretaria, meta, IN, Item, Custeio/
# Investimento, Código Ação, Unidade Orçamentária, Ação, Fonte, classif., V. Atualizado, V. Congelado, V. Disponível, Atualizado (Disponibilizado PDM), Congelado (Dispon. PDM), Disponível (Dispon. PDM), Custo 2021, Custo 2022, Custo 2023, Custo 2024, Custo TOTAL]
# Index: []

# %%
limpo.to_excel('dados_orcamento_limpos_4.xlsx')
