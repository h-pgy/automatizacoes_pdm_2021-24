# %%
from pathlib import Path
import pandas as pd
from openpyxl import load_workbook
import os
import numpy as np
import pickle

# %%
pd.set_option("display.max_columns", None)

# %%
PATH_FILES_ONE_DRIVE = Path(r'C:\Users\h-pgy\one_drive_prefs\OneDrive - Default Directory\Shared Documents\Estruturação do PDM 2021-2024\Elaboração PDM Versão Final')

# %%
class PlanilhaNotFound(ValueError):
    '''Raised quando nao consegue achar planilha para a meta'''

# %%
def listar_metas_ok():
    
    controle = pd.read_excel(PATH_FILES_ONE_DRIVE/'Controle das Devolutivas.xlsx')
    
    filtro_preench = controle['Aba Orçamento preenchida corretamente?'].str.lower().str.strip()=='sim'
    filtro_analis = controle['Aba orçamento já analisada?'].str.lower().str.strip()=='sim'
    
    for m in controle[~(filtro_preench&filtro_analis)]['Meta'].unique():
        print(f'Meta {m} não está ok no controle')
    
    return controle[filtro_preench&filtro_analis]['Meta'].values

# %%
def get_planilhas(folder_original):
        
        fpaths =  [os.path.join(folder_original, file) for file in 
                    os.listdir(folder_original) if 'xls' 
                    in file.split('.')[-1]]
        
        return fpaths

# %%
def read_workbook(file):

    wb = load_workbook(file, read_only=True, data_only=True)

    return wb

# %%
def match_planilha(wb, num_meta):
        
        sheet = wb['Ficha técnica Meta ']
        
        num_meta_planilha = sheet['C5'].value
        
        if str(num_meta_planilha) == str(num_meta):
            return True

# %%
def find_planilha(files, num_meta):
    
    for file in files:
        
        wb = read_workbook(file)
        
        if match_planilha(wb, num_meta):
            secretaria = wb['Ficha técnica Meta ']['C4'].value
            files.remove(file) # remove para dar uma otimizada nas próximas buscas
            return file, secretaria
    else:
        raise PlanilhaNotFound(f'Planilha não encontrada para a meta {num_meta}')

# %%
def planilhao(lista_ok = None, path_xls = None, lista_dfs = None):
    
    if path_xls is None:
        path_xls = PATH_FILES_ONE_DRIVE/'Fichas Metas\Devolutiva 11-jun'
        
    if lista_ok is None:
        lista_ok = listar_metas_ok()
        
    if lista_dfs is None:
        lista_dfs = []
    
    f_paths = get_planilhas(path_xls)
        
    for meta in lista_ok:
        print(f'Puxando dados meta {meta}')
        try:
            file, secretaria = find_planilha(f_paths, meta)
        except PlanilhaNotFound as e:
            print(e)
            continue
        df = pd.read_excel(file, sheet_name = 'Orçamento', thousands = '.',
                          dtype = {'Código Ação' : str})
        df['meta'] = meta
        df['secretaria'] = secretaria
        lista_dfs.append(df)
    
    return pd.concat(lista_dfs)

# %%
lista_dfs = []
df = planilhao(lista_dfs = lista_dfs)
# Out:
# Meta 1 não está ok no controle
# Meta 3.2 não está ok no controle
# Meta 53 não está ok no controle
# Meta 54 não está ok no controle
# Meta SMSU Nova 1 não está ok no controle
# Meta SGM.Nova2 não está ok no controle
# Meta nan não está ok no controle
# Puxando dados meta 2
# Puxando dados meta 3.1
# Puxando dados meta 4
# Puxando dados meta 5.1
# Puxando dados meta 6
# Puxando dados meta 7
# Puxando dados meta 8
# Puxando dados meta 9
# Puxando dados meta 10
# Puxando dados meta 11
# Puxando dados meta 12
# Puxando dados meta 13
# Puxando dados meta 14
# Puxando dados meta 15
# Puxando dados meta 16
# Puxando dados meta 17
# Puxando dados meta 18
# Puxando dados meta 19
# Puxando dados meta 20
# Puxando dados meta 21
# Puxando dados meta 22
# Puxando dados meta 23
# Puxando dados meta 24
# Puxando dados meta 25
# Puxando dados meta 26
# Puxando dados meta 27
# Puxando dados meta 28
# Puxando dados meta 29
# Puxando dados meta 30
# Puxando dados meta 31
# Puxando dados meta 32
# Puxando dados meta 33
# Puxando dados meta 34
# Puxando dados meta 35
# Puxando dados meta 36
# Puxando dados meta 37
# Puxando dados meta 38
# Puxando dados meta 39
# Puxando dados meta 40
# Puxando dados meta 41
# Puxando dados meta 42
# Puxando dados meta 43
# Puxando dados meta 44
# Puxando dados meta 45
# Puxando dados meta 46
# Puxando dados meta 47
# Puxando dados meta 48
# Puxando dados meta 49
# Puxando dados meta 50
# Puxando dados meta 51
# Puxando dados meta 52
# Puxando dados meta 55
# Puxando dados meta 56
# Puxando dados meta 57
# Puxando dados meta 58
# Puxando dados meta 59
# Puxando dados meta 60
# Puxando dados meta 61
# Puxando dados meta 62
# Puxando dados meta 63
# Puxando dados meta 64
# Puxando dados meta 65
# Puxando dados meta 66
# Puxando dados meta 67
# Puxando dados meta 68
# Puxando dados meta 69
# Puxando dados meta 70
# Puxando dados meta 71
# Puxando dados meta 72
# Puxando dados meta 73
# Puxando dados meta 74
# Puxando dados meta 75
# Puxando dados meta 52.1
# Puxando dados meta 54.2
# Puxando dados meta 54.3
# Puxando dados meta 52.2
# Puxando dados meta 54.4
# Puxando dados meta 52.3
# Puxando dados meta 3.2
# Puxando dados meta 5.2

# %%
with open('orcamento.pi', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('orcamento.pi', 'rb') as f:
    df = pickle.load(f)

# %%
def dropar_unnamed(df):
    
    unnameds = [col for col in df if
               col.startswith('Unnamed: ')]
    
    df.drop(unnameds, axis = 1, inplace = True)
    for col in df:
        if col.startswith('Unnamed: '):
            df.drop(col, axis = 1, )

# %%
dropar_unnamed(df)

# %%
sem_na = df.dropna(how='all', subset = [col for col in df.columns if col not in ('meta', 'secretaria')]).copy()

# %%
def pegar_objetivos(df):
    
    objetivos = pd.read_excel(PATH_FILES_ONE_DRIVE/'Metas com Objetivos atualizados 18-06-21.xlsx')
    
    merged = df.merge(objetivos, how = 'left', 
                      right_on = 'Nº meta PdM ',  left_on = 'meta').copy()
    
    merged.drop(['Redação da Meta PdM ','Nº meta PdM '],
               axis = 1, inplace = True)
    
    return merged

# %%
sem_na = pegar_objetivos(sem_na)

# %%
def arrumar_meta(item):
    
    item = str(item)
    
    antes, depois = item.split('.')
    
    if int(depois) > 0:
        return f'{antes}.{depois}'
    else:
        return antes

# %%
sem_na['meta'] = sem_na['meta'].apply(arrumar_meta)

# %%
def add_ponto_acao(item):
    
    item = str(item)
    
    if item == 'nan':
        return 'XX.XX.XXXX.XX'
    else:
        return f'{item[:2]}.{item[2:4]}.{item[4:8]}.{item[8:10]}'

# %%
def gerar_colunas_dotacao(df):
    
    
    df = df.copy()
    df['Código Ação'] = df['Código Ação'].apply(add_ponto_acao)
    df['Unidade Orçamentária'] = df['Código Ação'].apply(lambda x: '.'.join(x.split('.')[:2]))
    df['Ação'] = df['Código Ação'].apply(lambda x: x.split('.')[2])
    df['Fonte'] = df['Código Ação'].apply(lambda x: x.split('.')[3])
    
    return df

# %%
sem_na = gerar_colunas_dotacao(sem_na)

# %%
ordem_cols = [
    'Objetivo Estratégico Atualizado',
    'secretaria',
    'meta',
    'IN',
    'Item',
    'Custeio/\nInvestimento',
    'Código Ação',
    'Unidade Orçamentária',
    'Ação',
    'Fonte',
    'classif.',
    'V. Atualizado',
    'V. Congelado',
    'V. Disponível',
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024',
    'Custo TOTAL',
     
     ]

# %%
sem_na = sem_na[ordem_cols]

# %%
sem_na.to_excel('planilhao_orcamento_final_3.xlsx', index = False)

# %%
colunas_numericas = [
'V. Atualizado',
'V. Congelado',                       
'V. Disponível',                        
'Atualizado (Disponibilizado PDM)',
'Congelado (Dispon. PDM)',    
'Disponível (Dispon. PDM)',             
'Custo 2021',            
'Custo 2022',                          
'Custo 2023',                          
'Custo 2024',                          
'Custo TOTAL']

# %%
df[df.eq('Não se aplica').any(1)]
# Out:
#   IN Item Custeio/\nInvestimento    Código Ação  classif. V. Atualizado  \
# 0  a    1          Não se aplica  Não se aplica  execução           NaN
# 3  c    1          Não se aplica  Não se aplica  execução           NaN
#
#   V. Congelado V. Disponível Atualizado (Disponibilizado PDM)  \
# 0          NaN           NaN                    Não se aplica
# 3          NaN           NaN                    Não se aplica
#
#   Congelado (Dispon. PDM) Disponível (Dispon. PDM)     Custo 2021  \
# 0           Não se aplica                      NaN  Não se aplica
# 3           Não se aplica                      NaN            0.0
#
#       Custo 2022     Custo 2023     Custo 2024 Custo TOTAL  meta secretaria  \
# 0  Não se aplica  Não se aplica  Não se aplica         0.0  20.0        SME
# 3            0.0            0.0            0.0         0.0  21.0        SME
#
#    Registro da alteração  Suplementações previstas\n(Disponibilizado PDM)  \
# 0                    NaN                                              NaN
# 3                    NaN                                              NaN
#
#    Observações sobre as suplementações previstas
# 0                                            NaN
# 3                                            NaN

# %%
def solve_numero(item):
    
    if item == 'Não se aplica':
        return np.nan
    if type(item) in (float, int):
        return item
    elif type(item) is str:
        try:
            float(item)
        except ValueError:
            try:
                item = item.replace('.', '')
                item = item.replace(',', '.')
                return float(item)
            except ValueError:
                print(f'Item {item} fora do padrão')
                return np.nan
    else:
        print(type(item))

# %%
numerico = sem_na.copy()
for col in colunas_numericas:
    numerico[col] = numerico[col].apply(solve_numero)
# Out:
# Item 0.00
# 0.00 fora do padrão
# Item - fora do padrão
# Item - fora do padrão
# Item - fora do padrão

# %%
numerico.dtypes
# Out:
# Objetivo Estratégico Atualizado      object
# secretaria                           object
# meta                                 object
# IN                                   object
# Item                                 object
# Custeio/\nInvestimento               object
# Código Ação                          object
# Unidade Orçamentária                 object
# Ação                                 object
# Fonte                                object
# classif.                             object
# V. Atualizado                       float64
# V. Congelado                        float64
# V. Disponível                       float64
# Atualizado (Disponibilizado PDM)    float64
# Congelado (Dispon. PDM)             float64
# Disponível (Dispon. PDM)            float64
# Custo 2021                          float64
# Custo 2022                          float64
# Custo 2023                          float64
# Custo 2024                          float64
# Custo TOTAL                         float64
# dtype: object

# %%
n_pode_vazio = [
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024'
]

# %%
for col in n_pode_vazio:
    soma = numerico[col].isnull().sum()
    if  soma > 0:
        print(col, soma)
# Out:
# Atualizado (Disponibilizado PDM) 30
# Congelado (Dispon. PDM) 33
# Disponível (Dispon. PDM) 38
# Custo 2021 13
# Custo 2022 12
# Custo 2022 12
# Custo 2023 12
# Custo 2024 12

# %%
dropar_categoricas = (numerico['classif.'].isnull()|numerico['Custeio/\nInvestimento'].isnull())

# %%
numerico[dropar_categoricas]
# Out:
#                        Objetivo Estratégico Atualizado secretaria meta   IN  \
# 10                                                 NaN        SMS  5.1  NaN
# 452  Promover a transparência e a integridade dos ó...        CGM   73  NaN
# 502  Garantir à população atendimento integral em s...        SMS  3.2  NaN
#
#     Item Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação  \
# 10   NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 452  NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 502  NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
#
#     Fonte classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 10     XX      NaN            NaN           NaN            NaN
# 452    XX      NaN            NaN           NaN            NaN
# 502    XX      NaN            NaN           NaN            NaN
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 10                                NaN                      NaN
# 452                               NaN                      NaN
# 502                               NaN                      NaN
#
#      Disponível (Dispon. PDM)    Custo 2021    Custo 2022   Custo 2023  \
# 10                        NaN  1.127527e+06  3.287534e+05    328753.44
# 452                       NaN           NaN           NaN          NaN
# 502                       NaN  1.056518e+08  1.383475e+08  31999785.13
#
#       Custo 2024   Custo TOTAL
# 10     328753.44  2.113787e+06
# 452          NaN  1.500000e+05
# 502  30000000.00  3.059991e+08

# %%
limpo = numerico[~dropar_categoricas].copy()

# %%
dropar_numericas = (limpo['Atualizado (Disponibilizado PDM)'].isnull()|
                    limpo['Congelado (Dispon. PDM)'].isnull()|
                    limpo['Disponível (Dispon. PDM)'].isnull()|
                    limpo['Custo 2021'].isnull()|
                    limpo['Custo 2022'].isnull()|
                    limpo['Custo 2023'].isnull()|
                    limpo['Custo 2024'].isnull())

# %%
dropar_numericas.sum()
# Out:
# 51

# %%
limpo[dropar_numericas]
# Out:
#                        Objetivo Estratégico Atualizado   secretaria meta   IN  \
# 0    Garantir à população atendimento integral em s...          SMS    2    c
# 1    Garantir à população atendimento integral em s...          SMS    2    c
# 2    Garantir à população atendimento integral em s...          SMS  3.1    a
# 3    Garantir à população atendimento integral em s...          SMS  3.1    a
# 4    Garantir à população atendimento integral em s...          SMS    4    e
# 5                                                  NaN          SMS  5.1    c
# 6                                                  NaN          SMS  5.1    c
# 7                                                  NaN          SMS  5.1    c
# 8                                                  NaN          SMS  5.1    d
# 9                                                  NaN          SMS  5.1    d
# 11   Garantir à população atendimento integral em s...          SMS    6    a
# 12   Garantir à população atendimento integral em s...          SMS    7    b
# 13   Garantir à população atendimento integral em s...          SMS    7    c
# 14   Garantir à população atendimento integral em s...          SMS    7    c
# 87   Garantir à toda população em idade escolar o a...          SME   20    a
# 91   Garantir à toda população em idade escolar o a...          SME   20    d
# 92   Garantir à toda população em idade escolar o a...          SME   20    d
# 96   Garantir à toda população em idade escolar o a...          SME   21    c
# 110  Garantir à toda população em idade escolar o a...          SME   21    e
# 121  Democratizar o acesso a políticas públicas de ...         SEME   26    b
# 122  Democratizar o acesso a políticas públicas de ...         SEME   26    c
# 134  Ampliar a resiliência da cidade às chuvas, red...        SIURB   30    A
# 142  Ampliar a resiliência da cidade às chuvas, red...        SMSUB   31    A
# 146  Garantir a qualidade e segurança das vias públ...        SMSUB   33    A
# 147  Garantir a qualidade e segurança das vias públ...        SMSUB   33    A
# 193  Atingir grau de excelência em segurança viária...          SMT   37    a
# 264  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    c
# 265  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    d
# 266  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    e
# 267  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 268  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 269  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 270  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 282  Garantir o acesso ao Sistema Municipal de Tran...          SMT   44    a
# 386  Assegurar o acesso à internet como direito fun...         SMIT   57    e
# 407  Proteger, recuperar e aprimorar a qualidade am...  SVMA; SMSUB   62    H
# 408  Proteger, recuperar e aprimorar a qualidade am...  SVMA; SMSUB   62    H
# 409  Promover a saúde e o bem estar dos animais dom...          SMS   63    a
# 410  Promover a saúde e o bem estar dos animais dom...          SMS   63    b
# 411  Promover a saúde e o bem estar dos animais dom...          SMS   63    c
# 412  Promover a saúde e o bem estar dos animais dom...          SMS   63    d
# 413  Promover a saúde e o bem estar dos animais dom...          SMS   63    e
# 427  Proteger, recuperar e aprimorar a qualidade am...        SMSUB   67    I
# 449  Promover a transparência e a integridade dos ó...          CGM   73    c
# 450  Promover a transparência e a integridade dos ó...          CGM   73    e
# 497  1.0           Investimento  84.10.1507.00                84.10  1507
# 498  1.0           investimento  84.11.9204.01                84.11  9204
# 499  2.0           investimento  84.11.9204.01                84.11  9204
# 500  1.0           investimento  84.11.9204.00                84.11  9204
# 501  2.0           investimento  84.11.9204.01                84.11  9204
#
#     Fonte       classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 0      00       execução   1.000000e+03        1000.0   0.000000e+00
# 1      00       execução   1.135403e+08           0.0   1.135403e+08
# 2      01       execução   2.231112e+08           0.0   2.231112e+08
# 3      00  contrapartida   8.000200e+07        2000.0   8.000000e+07
# 4      00       execução   3.643934e+09        1000.0   3.643933e+09
# 5      00       execução   5.805541e+06        1000.0   5.804541e+06
# 6      00       execução   5.805541e+06        1000.0   5.804541e+06
# 7      00       execução   5.805541e+06        1000.0   5.804541e+06
# 8      00       execução   3.157500e+05           0.0   3.157500e+05
# 9      00       execução   3.157500e+05           0.0   3.157500e+05
# 11     00       execução   3.643934e+09        1000.0   3.643933e+09
# 12     00       execução   3.643934e+09        1000.0   3.643933e+09
# 13     00       execução   3.643934e+09        1000.0   3.643933e+09
# 14     00       execução   3.643934e+09        1000.0   3.643933e+09
# 87     pl       execução            NaN           NaN            NaN
# 91     00       execução   5.359134e+07           0.0   5.359134e+07
# 92     00       execução   1.435809e+07           0.0   1.435809e+07
# 96     pl       execução            NaN           NaN            NaN
# 110    00       execução   9.507020e+05           0.0   9.507020e+05
# 121    00       execução   2.501000e+06        1000.0   2.500000e+06
# 122    00       execução   2.501000e+06        1000.0   2.500000e+06
# 134    03       execução   1.895025e+08   189502484.0   0.000000e+00
# 142     x  contrapartida            NaN           NaN            NaN
# 146    00       execução   1.113350e+08           0.0   1.113350e+08
# 147    00       execução   1.113350e+08           0.0   1.113350e+08
# 193    08       execução   1.815000e+07    18150000.0   0.000000e+00
# 264    00       execução   2.250000e+09           0.0   2.250000e+09
# 265    00       execução   1.000000e+03        1000.0   0.000000e+00
# 266    00       execução   1.000000e+03        1000.0   0.000000e+00
# 267    00       execução   1.000000e+03        1000.0   0.000000e+00
# 268    00       execução   1.000000e+03        1000.0   0.000000e+00
# 269    00       execução   1.000000e+03        1000.0   0.000000e+00
# 270    00       execução   1.000000e+03        1000.0   0.000000e+00
# 282    00       execução   1.000000e+03        1000.0   0.000000e+00
# 386     X       execução            NaN           NaN            NaN
# 407     x       execução            NaN           NaN            NaN
# 408     x  contrapartida            NaN           NaN            NaN
# 409    00       execução   2.488223e+07     7200000.0   1.768223e+07
# 410    00       execução   2.021369e+09           0.0   2.021369e+09
# 411    00       execução   2.488223e+07     7200000.0   1.768223e+07
# 412    00       execução   2.488223e+07     7200000.0   1.768223e+07
# 413    00       execução   2.488223e+07     7200000.0   1.768223e+07
# 427    00       execução   2.327007e+07           0.0   2.327007e+07
# 449    00       execução   2.677409e+07        2000.0   2.677309e+07
# 450    00       execução   2.677409e+07        2000.0   2.677309e+07
# 451    00  contrapartida   3.750430e+05           0.0   3.750430e+05
# 497    00       execução   1.000000e+03        1000.0   0.000000e+00
# 498    01       execução   2.231112e+08           0.0   2.231112e+08
# 499    01  contrapartida            NaN           0.0   2.231112e+08
# 500    00       execução   8.000200e+07        2000.0   8.000000e+07
# 501    01  contrapartida   2.231112e+08           0.0   2.231112e+08
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 0                                 NaN                      NaN
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# 5                                 NaN                      NaN
# 6                                 NaN                      NaN
# 7                                 NaN                      NaN
# 8                                 NaN                      NaN
# 9                                 NaN                      NaN
# 11                                NaN                      NaN
# 12                                NaN                      NaN
# 13                                NaN                      NaN
# 14                                NaN                      NaN
# 87                                NaN                      NaN
# 91                               0.00             0.000000e+00
# 92                               0.00             0.000000e+00
# 96                                NaN                      NaN
# 110                              0.00             0.000000e+00
# 121                              0.00             0.000000e+00
# 122                              0.00             0.000000e+00
# 134                               NaN             1.895025e+08
# 142                        8599612.25             0.000000e+00
# 146                              0.00             0.000000e+00
# 147                              0.00             0.000000e+00
# 193                              0.00             0.000000e+00
# 264                              0.00             0.000000e+00
# 265                              0.00             0.000000e+00
# 266                              0.00             0.000000e+00
# 267                              0.00             0.000000e+00
# 268                              0.00             0.000000e+00
# 269                              0.00             0.000000e+00
# 270                              0.00             0.000000e+00
# 282                              0.00             0.000000e+00
# 386                              0.00             0.000000e+00
# 407                       33869399.79             2.406636e+06
# 408                       65101434.22             1.000000e+03
# 409                               NaN                      NaN
# 410                               NaN                      NaN
# 411                               NaN                      NaN
# 412                               NaN                      NaN
# 413                               NaN                      NaN
# 427                              0.00                      NaN
# 449                          15000.00                      NaN
# 450                          15000.00                      NaN
# 451                          16000.00                      NaN
# 497                               NaN                      NaN
# 498                               NaN                      NaN
# 499                               NaN                      NaN
# 500                               NaN                      NaN
# 501                               NaN                      NaN
#
#      Disponível (Dispon. PDM)    Custo 2021    Custo 2022    Custo 2023  \
# 0                         NaN  2.500000e+07  0.000000e+00  0.000000e+00
# 1                         NaN  5.000000e+06  1.500000e+07  1.500000e+07
# 2                         NaN  2.764035e+07  5.739074e+07  8.321800e+06
# 3                         NaN  2.764035e+07  5.739074e+07  8.321800e+06
# 4                         NaN  4.982958e+07  6.586751e+07  8.370344e+07
# 5                         NaN  4.640000e+05  1.440000e+05  1.440000e+05
# 6                         NaN  1.228150e+05  3.811500e+04  3.811500e+04
# 7                         NaN  1.007964e+05           NaN           NaN
# 8                         NaN  4.165200e+05  1.388400e+05  1.388400e+05
# 9                         NaN  2.339532e+04  7.798440e+03  7.798440e+03
# 11                        NaN  5.787494e+04  5.787494e+04  1.157499e+05
# 12                        NaN  1.500000e+06  1.500000e+06  1.500000e+06
# 13                        NaN  7.500000e+05  7.500000e+05  7.500000e+05
# 14                        NaN  7.500000e+05  7.500000e+05  7.500000e+05
# 87                        NaN           NaN           NaN           NaN
# 134  1.111058e+08  9.751634e+08
# 142           NaN  0.000000e+00
# 146  2.162281e+08  7.539555e+08
# 147  2.206132e+07  7.692458e+07
# 193  2.000000e+06  6.000000e+06
# 264           NaN           NaN
# 265           NaN  6.000000e+06
# 266           NaN  4.000000e+06
# 267           NaN           NaN
# 268           NaN  3.147381e+06
# 269           NaN  1.049127e+08
# 270           NaN  1.080601e+07
# 282  0.000000e+00  6.900000e+06
# 386           NaN  9.849706e+07
# 407  1.383022e+08  5.532086e+08
# 408  0.000000e+00  0.000000e+00
# 409  5.500000e+06  2.200000e+07
# 410  0.000000e+00  2.000000e+06
# 411  0.000000e+00  1.500000e+05
# 412  0.000000e+00  3.500000e+06
# 413  1.500000e+06  4.500000e+06
# 427  2.886885e+05  8.805000e+05
# 449  2.400000e+04  1.290000e+05
# 450  7.000000e+03  2.100000e+04
# 451  0.000000e+00  0.000000e+00
# 497  3.000000e+07  1.800000e+08
# 498  0.000000e+00  1.222649e+08
# 499  0.000000e+00  1.222649e+08
# 500  0.000000e+00  3.734209e+06
# 501  0.000000e+00  3.734209e+06

# %%
# a principio nao vamos limpar as numericas
#limpo = limpo[~dropar_numericas].copy()

# %%
limpo[limpo['Objetivo Estratégico Atualizado'].isnull()]
# Out:
#   Objetivo Estratégico Atualizado secretaria meta IN Item  \
# 5                             NaN        SMS  5.1  c  1.0
# 6                             NaN        SMS  5.1  c  2.0
# 7                             NaN        SMS  5.1  c  3.0
# 8                             NaN        SMS  5.1  d  1.0
# 9                             NaN        SMS  5.1  d  2.0
#
#   Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação Fonte  \
# 5                Custeio  84.28.2509.00                84.28  2509    00
# 6                Custeio  84.28.2509.00                84.28  2509    00
# 7                Custeio  84.28.2509.00                84.28  2509    00
# 8                Custeio  84.22.2818.00                84.22  2818    00
# 9                Custeio  84.22.2818.00                84.22  2818    00
#
#    classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 5  execução      5805541.0        1000.0      5804541.0
# 6  execução      5805541.0        1000.0      5804541.0
# 7  execução      5805541.0        1000.0      5804541.0
# 8  execução       315750.0           0.0       315750.0
# 9  execução       315750.0           0.0       315750.0
#
#    Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 5                               NaN                      NaN
# 6                               NaN                      NaN
# 7                               NaN                      NaN
# 8                               NaN                      NaN
# 9                               NaN                      NaN
#
#    Disponível (Dispon. PDM)  Custo 2021  Custo 2022  Custo 2023  Custo 2024  \
# 5                       NaN   464000.00   144000.00   144000.00   144000.00
# 6                       NaN   122815.00    38115.00    38115.00    38115.00
# 7                       NaN   100796.40         NaN         NaN         NaN
# 8                       NaN   416520.00   138840.00   138840.00   138840.00
# 9                       NaN    23395.32     7798.44     7798.44     7798.44
#
#    Custo TOTAL
# 5    896000.00
# 6    237160.00
# 7    100796.40
# 8    833040.00
# 9     46790.64

# %%
limpo.to_excel('orcamento_limpo_final_3.xlsx')
