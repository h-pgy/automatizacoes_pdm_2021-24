# %%
from pathlib import Path
import pandas as pd
from openpyxl import load_workbook
import os
import numpy as np
import pickle

# %%
pd.set_option("display.max_columns", None)

# %%
PATH_FILES_ONE_DRIVE = Path(r'C:\Users\h-pgy\one_drive_prefs\OneDrive - Default Directory\Shared Documents\Estruturação do PDM 2021-2024\Elaboração PDM Versão Final')

# %%
class PlanilhaNotFound(ValueError):
    '''Raised quando nao consegue achar planilha para a meta'''

# %%
def listar_metas_ok():
    
    controle = pd.read_excel(PATH_FILES_ONE_DRIVE/'Controle das Devolutivas.xlsx')
    
    filtro_preench = controle['Aba Orçamento preenchida corretamente?'].str.lower().str.strip()=='sim'
    filtro_analis = controle['Aba orçamento já analisada?'].str.lower().str.strip()=='sim'
    
    for m in controle[~(filtro_preench&filtro_analis)]['Meta'].unique():
        print(f'Meta {m} não está ok no controle')
    
    return controle[filtro_preench&filtro_analis]['Meta'].values

# %%
def get_planilhas(folder_original):
        
        fpaths =  [os.path.join(folder_original, file) for file in 
                    os.listdir(folder_original) if 'xls' 
                    in file.split('.')[-1]]
        
        return fpaths

# %%
def read_workbook(file):

    wb = load_workbook(file, read_only=True, data_only=True)

    return wb

# %%
def match_planilha(wb, num_meta):
        
        sheet = wb['Ficha técnica Meta ']
        
        num_meta_planilha = sheet['C5'].value
        
        if str(num_meta_planilha) == str(num_meta):
            return True

# %%
def find_planilha(files, num_meta):
    
    for file in files:
        
        wb = read_workbook(file)
        
        if match_planilha(wb, num_meta):
            secretaria = wb['Ficha técnica Meta ']['C4'].value
            files.remove(file) # remove para dar uma otimizada nas próximas buscas
            return file, secretaria
    else:
        raise PlanilhaNotFound(f'Planilha não encontrada para a meta {num_meta}')

# %%
def planilhao(lista_ok = None, path_xls = None, lista_dfs = None):
    
    if path_xls is None:
        path_xls = PATH_FILES_ONE_DRIVE/'Fichas Metas\Devolutiva 11-jun'
        
    if lista_ok is None:
        lista_ok = listar_metas_ok()
        
    if lista_dfs is None:
        lista_dfs = []
    
    f_paths = get_planilhas(path_xls)
        
    for meta in lista_ok:
        print(f'Puxando dados meta {meta}')
        try:
            file, secretaria = find_planilha(f_paths, meta)
        except PlanilhaNotFound as e:
            print(e)
            continue
        df = pd.read_excel(file, sheet_name = 'Orçamento', thousands = '.',
                          dtype = {'Código Ação' : str})
        df['meta'] = meta
        df['secretaria'] = secretaria
        lista_dfs.append(df)
    
    return pd.concat(lista_dfs)

# %%
lista_dfs = []
df = planilhao(lista_dfs = lista_dfs)
# Out:
# Meta 1 não está ok no controle
# Meta 53 não está ok no controle
# Meta 54 não está ok no controle
# Meta 69 não está ok no controle
# Meta SMSU Nova 1 não está ok no controle
# Meta SGM.Nova1 não está ok no controle
# Meta SGM.Nova2 não está ok no controle
# Meta nan não está ok no controle
# Puxando dados meta 2
# Puxando dados meta 3.1
# Puxando dados meta 4
# Puxando dados meta 5.1
# Puxando dados meta 6
# Puxando dados meta 7
# Puxando dados meta 8
# Puxando dados meta 9
# Puxando dados meta 10
# Puxando dados meta 11
# Puxando dados meta 12
# Puxando dados meta 13
# Puxando dados meta 14
# Puxando dados meta 15
# Puxando dados meta 16
# Puxando dados meta 17
# Puxando dados meta 18
# Puxando dados meta 19
# Puxando dados meta 20
# Puxando dados meta 21
# Puxando dados meta 22
# Puxando dados meta 23
# Puxando dados meta 24
# Puxando dados meta 25
# Puxando dados meta 26
# Puxando dados meta 27
# Puxando dados meta 28
# Puxando dados meta 29
# Puxando dados meta 30
# Puxando dados meta 31
# Puxando dados meta 32
# Puxando dados meta 33
# Puxando dados meta 34
# Puxando dados meta 35
# Puxando dados meta 36
# Puxando dados meta 37
# Puxando dados meta 38
# Puxando dados meta 39
# Puxando dados meta 40
# Puxando dados meta 41
# Puxando dados meta 42
# Puxando dados meta 43
# Puxando dados meta 44
# Puxando dados meta 45
# Puxando dados meta 46
# Puxando dados meta 47
# Puxando dados meta 48
# Puxando dados meta 49
# Puxando dados meta 50
# Puxando dados meta 51
# Puxando dados meta 52
# Puxando dados meta 55
# Puxando dados meta 56
# Puxando dados meta 57
# Puxando dados meta 58
# Puxando dados meta 59
# Puxando dados meta 60
# Puxando dados meta 61
# Puxando dados meta 62
# Puxando dados meta 63
# Puxando dados meta 64
# Puxando dados meta 65
# Puxando dados meta 66
# Puxando dados meta 67
# Puxando dados meta 68
# Puxando dados meta 70
# Puxando dados meta 71
# Puxando dados meta 72
# Puxando dados meta 73
# Puxando dados meta 74
# Puxando dados meta 75
# Puxando dados meta 52.1
# Puxando dados meta 54.2
# Puxando dados meta 54.3
# Puxando dados meta 52.2
# Puxando dados meta 54.4
# Puxando dados meta 52.3
# Puxando dados meta 3.2
# Puxando dados meta 5.2

# %%
with open('orcamento.pi', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('orcamento.pi', 'rb') as f:
    df = pickle.load(f)

# %%
def dropar_unnamed(df):
    
    unnameds = [col for col in df if
               col.startswith('Unnamed: ')]
    
    df.drop(unnameds, axis = 1, inplace = True)
    for col in df:
        if col.startswith('Unnamed: '):
            df.drop(col, axis = 1, )

# %%
dropar_unnamed(df)

# %%
sem_na = df.dropna(how='all', subset = [col for col in df.columns if col not in ('meta', 'secretaria')]).copy()

# %%
def pegar_objetivos(df):
    
    objetivos = pd.read_excel(PATH_FILES_ONE_DRIVE/'Metas com Objetivos atualizados 18-06-21.xlsx')
    
    merged = df.merge(objetivos, how = 'left', 
                      right_on = 'Nº meta PdM ',  left_on = 'meta').copy()
    
    merged.drop(['Redação da Meta PdM ','Nº meta PdM '],
               axis = 1, inplace = True)
    
    return merged

# %%
sem_na = pegar_objetivos(sem_na)

# %%
def arrumar_meta(item):
    
    item = str(item)
    
    antes, depois = item.split('.')
    
    if int(depois) > 0:
        return f'{antes}.{depois}'
    else:
        return antes

# %%
sem_na['meta'] = sem_na['meta'].apply(arrumar_meta)

# %%
def add_ponto_acao(item):
    
    item = str(item)
    
    if item == 'nan':
        return 'XX.XX.XXXX.XX'
    else:
        return f'{item[:2]}.{item[2:4]}.{item[4:8]}.{item[8:10]}'

# %%
def gerar_colunas_dotacao(df):
    
    
    df = df.copy()
    df['Código Ação'] = df['Código Ação'].apply(add_ponto_acao)
    df['Unidade Orçamentária'] = df['Código Ação'].apply(lambda x: '.'.join(x.split('.')[:2]))
    df['Ação'] = df['Código Ação'].apply(lambda x: x.split('.')[2])
    df['Fonte'] = df['Código Ação'].apply(lambda x: x.split('.')[3])
    
    return df

# %%
sem_na = gerar_colunas_dotacao(sem_na)

# %%
ordem_cols = [
    'Objetivo Estratégico Atualizado',
    'secretaria',
    'meta',
    'IN',
    'Item',
    'Custeio/\nInvestimento',
    'Código Ação',
    'Unidade Orçamentária',
    'Ação',
    'Fonte',
    'classif.',
    'V. Atualizado',
    'V. Congelado',
    'V. Disponível',
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024',
    'Custo TOTAL',
     
     ]

# %%
sem_na = sem_na[ordem_cols]

# %%
sem_na.to_excel('planilhao_orcamento_final.xlsx', index = False)

# %%
colunas_numericas = [
'V. Atualizado',
'V. Congelado',                       
'V. Disponível',                        
'Atualizado (Disponibilizado PDM)',
'Congelado (Dispon. PDM)',    
'Disponível (Dispon. PDM)',             
'Custo 2021',            
'Custo 2022',                          
'Custo 2023',                          
'Custo 2024',                          
'Custo TOTAL']

# %%
df[df.eq('Não se aplica').any(1)]
# Out:
#   IN Item Custeio/\nInvestimento    Código Ação  classif. V. Atualizado  \
# 0  a    1          Não se aplica  Não se aplica  execução           NaN
# 3  c    1          Não se aplica  Não se aplica  execução           NaN
#
#   V. Congelado V. Disponível Atualizado (Disponibilizado PDM)  \
# 0          NaN           NaN                    Não se aplica
# 3          NaN           NaN                    Não se aplica
#
#   Congelado (Dispon. PDM) Disponível (Dispon. PDM)     Custo 2021  \
# 0           Não se aplica                      NaN  Não se aplica
# 3           Não se aplica                      NaN            0.0
#
#       Custo 2022     Custo 2023     Custo 2024 Custo TOTAL  meta secretaria  \
# 0  Não se aplica  Não se aplica  Não se aplica         0.0  20.0        SME
# 3            0.0            0.0            0.0         0.0  21.0        SME
#
#    Registro da alteração  Suplementações previstas\n(Disponibilizado PDM)  \
# 0                    NaN                                              NaN
# 3                    NaN                                              NaN
#
#    Observações sobre as suplementações previstas
# 0                                            NaN
# 3                                            NaN

# %%
def solve_numero(item):
    
    if item == 'Não se aplica':
        return np.nan
    if type(item) in (float, int):
        return item
    elif type(item) is str:
        try:
            float(item)
        except ValueError:
            try:
                item = item.replace('.', '')
                item = item.replace(',', '.')
                return float(item)
            except ValueError:
                print(f'Item {item} fora do padrão')
                return np.nan
    else:
        print(type(item))

# %%
numerico = sem_na.copy()
for col in colunas_numericas:
    numerico[col] = numerico[col].apply(solve_numero)
# Out:
# Item 0.00
# 0.00 fora do padrão

# %%
numerico.dtypes
# Out:
# Objetivo Estratégico Atualizado      object
# secretaria                           object
# meta                                 object
# IN                                   object
# Item                                 object
# Custeio/\nInvestimento               object
# Código Ação                          object
# Unidade Orçamentária                 object
# Ação                                 object
# Fonte                                object
# classif.                             object
# V. Atualizado                       float64
# V. Congelado                        float64
# V. Disponível                       float64
# Atualizado (Disponibilizado PDM)    float64
# Congelado (Dispon. PDM)             float64
# Disponível (Dispon. PDM)            float64
# Custo 2021                          float64
# Custo 2022                          float64
# Custo 2023                          float64
# Custo 2024                          float64
# Custo TOTAL                         float64
# dtype: object

# %%
n_pode_vazio = [
    'Atualizado (Disponibilizado PDM)',
    'Congelado (Dispon. PDM)',
    'Disponível (Dispon. PDM)',
    'Custo 2021',
    'Custo 2022',
    'Custo 2022',
    'Custo 2023',
    'Custo 2024'
]

# %%
for col in n_pode_vazio:
    soma = numerico[col].isnull().sum()
    if  soma > 0:
        print(col, soma)
# Out:
# Atualizado (Disponibilizado PDM) 7
# Congelado (Dispon. PDM) 10
# Disponível (Dispon. PDM) 16
# Custo 2021 14
# Custo 2022 12
# Custo 2022 12
# Custo 2023 11
# Custo 2024 11

# %%
dropar_categoricas = (numerico['classif.'].isnull()|numerico['Custeio/\nInvestimento'].isnull())

# %%
numerico[dropar_categoricas]
# Out:
#                        Objetivo Estratégico Atualizado secretaria meta   IN  \
# 2    Garantir à população atendimento integral em s...        SMS    2  NaN
# 6    Garantir à população atendimento integral em s...        SMS    4  NaN
# 441  Promover a transparência e a integridade dos ó...        CGM   73  NaN
#
#     Item Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação  \
# 2    NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 6    NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
# 441  NaN                    NaN  XX.XX.XXXX.XX                XX.XX  XXXX
#
#     Fonte classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 2      XX      NaN            NaN           NaN            NaN
# 6      XX      NaN            NaN           NaN            NaN
# 441    XX      NaN            NaN           NaN            NaN
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 2                                 NaN                      NaN
# 6                                 NaN                      NaN
# 441                               NaN                      NaN
#
#      Disponível (Dispon. PDM)  Custo 2021  Custo 2022  Custo 2023  Custo 2024  \
# 2                         NaN         NaN         NaN         0.0         NaN
# 6                         NaN         NaN         NaN         NaN         0.0
# 441                       NaN         NaN         NaN         NaN         NaN
#
#      Custo TOTAL
# 2            NaN
# 6            NaN
# 441     150000.0

# %%
limpo = numerico[~dropar_categoricas].copy()

# %%
dropar_numericas = (limpo['Atualizado (Disponibilizado PDM)'].isnull()|
                    limpo['Congelado (Dispon. PDM)'].isnull()|
                    limpo['Disponível (Dispon. PDM)'].isnull()|
                    limpo['Custo 2021'].isnull()|
                    limpo['Custo 2022'].isnull()|
                    limpo['Custo 2023'].isnull()|
                    limpo['Custo 2024'].isnull())

# %%
dropar_numericas.sum()
# Out:
# 28

# %%
limpo[dropar_numericas]
# Out:
#                        Objetivo Estratégico Atualizado   secretaria meta   IN  \
# 82   Garantir à toda população em idade escolar o a...          SME   20    a
# 86   Garantir à toda população em idade escolar o a...          SME   20    d
# 87   Garantir à toda população em idade escolar o a...          SME   20    d
# 91   Garantir à toda população em idade escolar o a...          SME   21    c
# 105  Garantir à toda população em idade escolar o a...          SME   21    e
# 116  Democratizar o acesso a políticas públicas de ...         SEME   26    b
# 117  Democratizar o acesso a políticas públicas de ...         SEME   26    c
# 129  Ampliar a resiliência da cidade às chuvas, red...        SIURB   30    A
# 137  Ampliar a resiliência da cidade às chuvas, red...        SMSUB   31    A
# 141  Garantir a qualidade e segurança das vias públ...        SMSUB   33    A
# 142  Garantir a qualidade e segurança das vias públ...        SMSUB   33    A
# 188  Atingir grau de excelência em segurança viária...          SMT   37    a
# 259  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    c
# 260  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    d
# 261  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    e
# 262  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 263  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 264  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 265  Garantir o acesso ao Sistema Municipal de Tran...          SMT   42    g
# 277  Garantir o acesso ao Sistema Municipal de Tran...          SMT   44    a
# 380  Assegurar o acesso à internet como direito fun...         SMIT   57    d
# 401  Proteger, recuperar e aprimorar a qualidade am...  SVMA; SMSUB   62    H
# 402  Proteger, recuperar e aprimorar a qualidade am...  SVMA; SMSUB   62    H
# 417  Proteger, recuperar e aprimorar a qualidade am...        SMSUB   67    I
# 438  Promover a transparência e a integridade dos ó...          CGM   73    c
# 439  Promover a transparência e a integridade dos ó...          CGM   73    e
# 440  Promover a transparência e a integridade dos ó...          CGM   73  NaN
# 491                                                NaN          SMS  3.2    B
#
#     Item Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação  \
# 82     1          Não se aplica  Nã.o .se a.pl                Nã.o   se a
# 86     2                Custeio  16.10.2831.00                16.10  2831
# 87     3                Custeio  16.10.2180.00                16.10  2180
# 91     1          Não se aplica  Nã.o .se a.pl                Nã.o   se a
# 105    1                Custeio  16.10.2820.00                16.10  2820
# 116    2                Custeio  19.10.2397.00                19.10  2397
# 117    3                Custeio  19.10.2397.00                19.10  2397
# 129    3           Investimento  86.22.5013.03                86.22  5013
# 137    1                Custeio  xx..x.x.xx.xx                  xx.     x
# 141    3                Custeio  12.10.2340.00                12.10  2340
# 142    4                Custeio  12.10.2340.00                12.10  2340
# 188   42           Investimento  98.20.3757.08                98.20  3757
# 259    1                Custeio  20.10.4701.00                20.10  4701
# 260    1           Investimento  20.10.1095.00                20.10  1095
# 261    1           Investimento  20.10.1095.00                20.10  1095
# 262    1           Investimento  20.10.1095.00                20.10  1095
# 263    2           Investimento  20.10.1095.00                20.10  1095
# 264    3           Investimento  20.10.1095.00                20.10  1095
# 265    4           Investimento  20.10.1095.00                20.10  1095
# 277    8           Investimento  20.10.1099.00                20.10  1099
# 380    1                custeio  23.10.4305.00                23.10  4305
# 401    1                Custeio  xx..x.x.xx.xx                  xx.     x
# 402    1                Custeio  xx..x.x.xx.xx                  xx.     x
# 417    2           investimento  81.10.6006.00                81.10  6006
# 438  1.0                Custeio  32.10.2100.00                32.10  2100
# 439  1.0                Custeio  32.10.2100.00                32.10  2100
# 440  NaN                Custeio  32.10.8262.00                32.10  8262
# 491    1           investimento  84.11.9204.00                84.11  9204
#
#     Fonte       classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 82     pl       execução            NaN           NaN            NaN
# 86     00       execução   5.359134e+07           0.0   5.359134e+07
# 87     00       execução   1.435809e+07           0.0   1.435809e+07
# 91     pl       execução            NaN           NaN            NaN
# 105    00       execução   9.507020e+05           0.0   9.507020e+05
# 116    00       execução   2.501000e+06        1000.0   2.500000e+06
# 117    00       execução   2.501000e+06        1000.0   2.500000e+06
# 129    03       execução   1.895025e+08   189502484.0   0.000000e+00
# 137     x  contrapartida            NaN           NaN            NaN
# 141    00       execução   1.113350e+08           0.0   1.113350e+08
# 142    00       execução   1.113350e+08           0.0   1.113350e+08
# 188    08       execução   1.815000e+07    18150000.0   0.000000e+00
# 259    00       execução   2.250000e+09           0.0   2.250000e+09
# 260    00       execução   1.000000e+03        1000.0   0.000000e+00
# 261    00       execução   1.000000e+03        1000.0   0.000000e+00
# 262    00       execução   1.000000e+03        1000.0   0.000000e+00
# 263    00       execução   1.000000e+03        1000.0   0.000000e+00
# 264    00       execução   1.000000e+03        1000.0   0.000000e+00
# 265    00       execução   1.000000e+03        1000.0   0.000000e+00
# 277    00       execução   1.000000e+03        1000.0   0.000000e+00
# 380    00       execução   4.100000e+05           0.0   4.100000e+05
# 401     x       execução            NaN           NaN            NaN
# 402     x  contrapartida            NaN           NaN            NaN
# 417    00       execução   2.327007e+07           0.0   2.327007e+07
# 438    00       execução   2.677409e+07        2000.0   2.677309e+07
# 439    00       execução   2.677409e+07        2000.0   2.677309e+07
# 440    00  contrapartida   3.750430e+05           0.0   3.750430e+05
# 491    00       execução   8.000200e+07        2000.0   8.000000e+07
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 82                                NaN                      NaN
# 86                               0.00             0.000000e+00
# 87                               0.00             0.000000e+00
# 91                                NaN                      NaN
# 105                              0.00             0.000000e+00
# 116                              0.00             0.000000e+00
# 117                              0.00             0.000000e+00
# 129                               NaN             1.895025e+08
# 137                        8599612.25             0.000000e+00
# 141                              0.00             0.000000e+00
# 142                              0.00             0.000000e+00
# 188                              0.00             0.000000e+00
# 259                              0.00             0.000000e+00
# 260                              0.00             0.000000e+00
# 261                              0.00             0.000000e+00
# 262                              0.00             0.000000e+00
# 263                              0.00             0.000000e+00
# 264                              0.00             0.000000e+00
# 265                              0.00             0.000000e+00
# 277                              0.00             0.000000e+00
# 380                              0.00             0.000000e+00
# 401                       33869399.79             2.406636e+06
# 402                       65101434.22             1.000000e+03
# 417                              0.00                      NaN
# 438                          15000.00                      NaN
# 439                          15000.00                      NaN
# 440                          16000.00                      NaN
# 491                               NaN                      NaN
#
#      Disponível (Dispon. PDM)    Custo 2021    Custo 2022    Custo 2023  \
# 82                        NaN           NaN           NaN           NaN
# 86                        NaN  0.000000e+00  5.040000e+03  5.292000e+03
# 87                        NaN  0.000000e+00  6.788250e+03  7.127660e+03
# 91                        NaN  0.000000e+00  0.000000e+00  0.000000e+00
# 105                       NaN  0.000000e+00  1.050000e+06  0.000000e+00
# 116                       NaN  0.000000e+00  5.550000e+05  1.110000e+06
# 117                       NaN  0.000000e+00  1.105000e+06  1.215500e+06
# 129                      0.00  3.906923e+08  2.813403e+08  1.920251e+08
# 137                8599612.25           NaN           NaN           NaN
# 141                       NaN  1.624554e+08  1.787009e+08  1.965710e+08
# 142                       NaN  1.657500e+07  1.823250e+07  2.005575e+07
# 188                      0.00           NaN  2.000000e+06  2.000000e+06
# 259                      0.00           NaN           NaN           NaN
# 260                      0.00           NaN           NaN           NaN
# 261                      0.00           NaN           NaN           NaN
# 262                      0.00           NaN           NaN           NaN
# 263                      0.00           NaN           NaN           NaN
# 264                      0.00           NaN           NaN           NaN
# 265                      0.00           NaN           NaN           NaN
# 277                      0.00           NaN  6.900000e+06  0.000000e+00
# 380                       NaN  1.000000e+05  1.000000e+05  1.000000e+05
# 401                       NaN  1.383022e+08  1.383022e+08  1.383022e+08
# 402                       NaN  0.000000e+00  0.000000e+00  0.000000e+00
# 417                      0.00  0.000000e+00  2.886885e+05  3.031230e+05
# 438                  15000.00  3.100000e+04  4.200000e+04  3.200000e+04
# 439                  15000.00  0.000000e+00  7.000000e+03  7.000000e+03
# 440                  16000.00  0.000000e+00  0.000000e+00  0.000000e+00
# 491                       NaN  2.000000e+06  4.000000e+06  2.000000e+06
#
#        Custo 2024   Custo TOTAL
# 82            NaN  0.000000e+00
# 86   5.556600e+03  1.588860e+04
# 87   7.484050e+03  2.139996e+04
# 91   0.000000e+00  0.000000e+00
# 105  1.050000e+06  2.100000e+06
# 116  1.665000e+06  3.330000e+06
# 117  1.337050e+06  3.657550e+06
# 129  1.111058e+08  9.751634e+08
# 137           NaN  0.000000e+00
# 141  2.162281e+08  7.539555e+08
# 142  2.206132e+07  7.692458e+07
# 188  2.000000e+06  6.000000e+06
# 259           NaN           NaN
# 260           NaN  6.000000e+06
# 261           NaN  4.000000e+06
# 262           NaN           NaN
# 263           NaN  3.147381e+06
# 264           NaN  1.049127e+08
# 265           NaN  1.080601e+07
# 277  0.000000e+00  6.900000e+06
# 380  1.000000e+05  4.000000e+05
# 401  1.383022e+08  5.532086e+08
# 402  0.000000e+00  0.000000e+00
# 417  2.886885e+05  8.805000e+05
# 438  2.400000e+04  1.290000e+05
# 439  7.000000e+03  2.100000e+04
# 440  0.000000e+00  0.000000e+00
# 491  0.000000e+00  8.000000e+06

# %%
# a principio nao vamos limpar as numericas
#limpo = limpo[~dropar_numericas].copy()

# %%
limpo[limpo['Objetivo Estratégico Atualizado'].isnull()]
# Out:
#     Objetivo Estratégico Atualizado secretaria meta IN Item  \
# 486                             NaN        SMS  3.2  C    1
# 487                             NaN        SMS  3.2  C    2
# 488                             NaN        SMS  3.2  C    3
# 489                             NaN        SMS  3.2  C    4
# 490                             NaN        SMS  3.2  A    1
# 491                             NaN        SMS  3.2  B    1
#
#     Custeio/\nInvestimento    Código Ação Unidade Orçamentária  Ação Fonte  \
# 486           investimento  84.11.9204.01                84.11  9204    01
# 487           investimento  84.11.9204.01                84.11  9204    01
# 488           investimento  84.11.9204.00                84.11  9204    00
# 489           investimento  84.11.9204.01                84.11  9204    01
# 490           investimento  84.11.9204.00                84.11  9204    00
# 491           investimento  84.11.9204.00                84.11  9204    00
#
#      classif.  V. Atualizado  V. Congelado  V. Disponível  \
# 486  execução    223111204.0           0.0    223111204.0
# 487  execução            NaN           0.0    223111204.0
# 488  execução     80002000.0        2000.0     80000000.0
# 489  execução    223111204.0           0.0    223111204.0
# 490  execução     80002000.0        2000.0     80000000.0
# 491  execução     80002000.0        2000.0     80000000.0
#
#      Atualizado (Disponibilizado PDM)  Congelado (Dispon. PDM)  \
# 486                               0.0                      0.0
# 487                               0.0                      0.0
# 488                               0.0                      0.0
# 489                               0.0                      0.0
# 490                               0.0                      0.0
# 491                               NaN                      NaN
#
#      Disponível (Dispon. PDM)  Custo 2021   Custo 2022  Custo 2023  \
# 486                       0.0   2000000.0   28000000.0   5000000.0
# 487                       0.0   2000000.0   28000000.0   5000000.0
# 488                       0.0   2000000.0   28000000.0   5000000.0
# 489                       0.0  15000000.0   15000000.0  15000000.0
# 490                       0.0  40000000.0  100000000.0  60000000.0
# 491                       NaN   2000000.0    4000000.0   2000000.0
#
#      Custo 2024  Custo TOTAL
# 486   5000000.0   40000000.0
# 487   5000000.0   40000000.0
# 488   5000000.0   40000000.0
# 489  15000000.0   60000000.0
# 490         0.0  200000000.0
# 491         0.0    8000000.0

# %%
limpo.to_excel('orcamento_limpo_final.xlsx')
